# %% [markdown]
# PRACTICAL 2 - Insertion Sort Real World Application
#
# dataset used - Lamborghini Car Data

# %%
# !pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mani787060/lamborghini-car-specification")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.48k/2.48k [00:00<00:00, 2.59MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mani787060/lamborghini-car-specification/versions/1

# %%
# !wget https://raw.githubusercontent.com/HemantkMCA25/DAA_Practical/refs/heads/main/youtube_top100_2025_songs.csv
# Out:
# --2026-01-27 15:13:58--  https://raw.githubusercontent.com/HemantkMCA25/DAA_Practical/refs/heads/main/youtube_top100_2025_songs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6725 (6.6K) [text/plain]
# Saving to: ‘youtube_top100_2025_songs.csv.2’
#
# youtube_top100_2025 100%[===================>]   6.57K  --.-KB/s    in 0s
#
# 2026-01-27 15:13:58 (71.5 MB/s) - ‘youtube_top100_2025_songs.csv.2’ saved [6725/6725]
