# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("comparisons.csv")
df
# Out:
#      n  avg_age  avg_name  avg_age_then_name
# 0   10     28.6      24.6               37.8
# 1   20    112.0     110.7              134.1
# 2   30    242.4     222.8              277.5
# 3   40    427.0     414.2              478.1
# 4   50    643.5     646.3              713.6
# 5   60    874.5     881.9              965.9
# 6   70   1213.6    1191.9             1326.7
# 7   80   1599.3    1572.1             1734.0
# 8   90   1941.9    1891.8             2096.0
# 9  100   2408.4    2362.0             2594.3

# %%
plt.figure(figsize=(8,5))
plt.plot(df["n"], df["avg_age"],  marker="o", linestyle="-", label="Avg comparisons (Age)")
plt.plot(df["n"], df["avg_name"], marker="s", linestyle="-", label="Avg comparisons (Name)")
plt.plot(df["n"], df["avg_age_then_name"], marker="^", linestyle="-", label="Avg comparisons (Name→Age)")

plt.xlabel("n (records per file)")
plt.ylabel("Average number of comparisons")
plt.title("Insertion Sort — Average Comparisons vs n")
plt.grid(True, linestyle="--", alpha=0.4)
plt.legend()
plt.tight_layout()
plt.savefig("avg_comparisons.png", dpi=200)
print("Saved plot to avg_comparisons.png")
# Out:
# Saved plot to avg_comparisons.png
